# %%
import pandas as pd
from pymongo import MongoClient

# %%
df = pd.read_csv("cleaned_crypto_data.csv")
df.head()
# Out:
#    Unnamed: 0        open        high         low       close  volume  \
# 0           0  112.900002  118.800003  107.142998  115.910004     0.0
# 1           1    3.493130    3.692460    3.346060    3.590890     0.0
# 2           2  115.980003  124.663002  106.639999  112.300003     0.0
# 3           3    3.594220    3.781020    3.116020    3.371250     0.0
# 4           4  112.250000  113.444000   97.699997  111.500000     0.0
#
#       marketCap                 timestamp crypto_name        date
# 0  1.288693e+09  2013-05-05T23:59:59.999Z     Bitcoin  2013-05-05
# 1  6.229819e+07  2013-05-05T23:59:59.999Z    Litecoin  2013-05-05
# 2  1.249023e+09  2013-05-06T23:59:59.999Z     Bitcoin  2013-05-06
# 3  5.859436e+07  2013-05-06T23:59:59.999Z    Litecoin  2013-05-06
# 4  1.240594e+09  2013-05-07T23:59:59.999Z     Bitcoin  2013-05-07

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 72946 entries, 0 to 72945
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   open         72946 non-null  float64
#  1   high         72946 non-null  float64
#  2   low          72946 non-null  float64
#  3   close        72946 non-null  float64
#  4   volume       72946 non-null  float64
#  5   marketCap    72946 non-null  float64
#  6   timestamp    72946 non-null  str
#  7   crypto_name  72946 non-null  str
#  8   date         72946 non-null  str
# dtypes: float64(6), str(3)
# memory usage: 5.0 MB

# %%
client = MongoClient(
    "mongodb+srv://tkashyap22june_db_user:m0wEHg8FcG3o1A1j@cluster0.3nziyuv.mongodb.net/"
)

# %%
client.admin.command("ping")
print("✅ Connected")
# Out:
# ✅ Connected

# %%
db = client["crypto_db"]
collection = db["crypto_database"]

# %%
records = df.to_dict("records")
result = collection.insert_many(records)

# %%
print("✅ Uploaded", len(result.inserted_ids), "documents")
# Out:
# ✅ Uploaded 72946 documents

# %%
print(collection.count_documents({}))
# Out:
# 72946

# %%
for doc in collection.find().limit(5):
    print(doc)
# Out:
# {'_id': ObjectId('6a12748dd1d1eaccfe340ab7'), 'open': 112.9000015259, 'high': 118.8000030518, 'low': 107.1429977417, 'close': 115.9100036621, 'volume': 0.0, 'marketCap': 1288693175.5, 'timestamp': '2013-05-05T23:59:59.999Z', 'crypto_name': 'Bitcoin', 'date': '2013-05-05'}
# {'_id': ObjectId('6a12748dd1d1eaccfe340ab8'), 'open': 3.4931299686, 'high': 3.6924600601, 'low': 3.3460600376, 'close': 3.5908899307, 'volume': 0.0, 'marketCap': 62298185.4291, 'timestamp': '2013-05-05T23:59:59.999Z', 'crypto_name': 'Litecoin', 'date': '2013-05-05'}
# {'_id': ObjectId('6a12748dd1d1eaccfe340ab9'), 'open': 115.9800033569, 'high': 124.6630020142, 'low': 106.6399993896, 'close': 112.3000030518, 'volume': 0.0, 'marketCap': 1249023060.0, 'timestamp': '2013-05-06T23:59:59.999Z', 'crypto_name': 'Bitcoin', 'date': '2013-05-06'}
# {'_id': ObjectId('6a12748dd1d1eaccfe340aba'), 'open': 3.594219923, 'high': 3.7810199261, 'low': 3.1160199642, 'close': 3.3712499142, 'volume': 0.0, 'marketCap': 58594361.235, 'timestamp': '2013-05-06T23:59:59.999Z', 'crypto_name': 'Litecoin', 'date': '2013-05-06'}
# {'_id': ObjectId('6a12748dd1d1eaccfe340abb'), 'open': 112.25, 'high': 113.4440002441, 'low': 97.6999969482, 'close': 111.5, 'volume': 0.0, 'marketCap': 1240593600.0, 'timestamp': '2013-05-07T23:59:59.999Z', 'crypto_name': 'Bitcoin', 'date': '2013-05-07'}
